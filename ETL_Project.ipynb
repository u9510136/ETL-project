# %%
import requests
import json
import pandas as pd

# %%
url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1960/1979/usa"
response = requests.get(url).json()
usa_60_79_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/usa"
response = requests.get(url).json()
usa_80_99_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1960/1979/chn"
response = requests.get(url).json()
chn_60_79_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/chn"
response = requests.get(url).json()
chn_80_99_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1960/1979/bra"
response = requests.get(url).json()
bra_60_79_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/bra"
response = requests.get(url).json()
bra_80_99_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1960/1979/deu"
response = requests.get(url).json()
deu_60_79_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/deu"
response = requests.get(url).json()
deu_80_99_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1960/1979/ind"
response = requests.get(url).json()
ind_60_79_temp = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/tas/1980/1999/ind"
response = requests.get(url).json()
ind_80_99_temp = response[0]["monthVals"]

# print(json.dumps(response, indent=4, sort_keys=True))

# %%
# response[0]["monthVals"]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
temp_dic = {
    "Months": months,
    "USA 1960-1979": usa_60_79_temp,
    "USA 1980-1999": usa_80_99_temp,
    "Brazil 1960-1979": bra_60_79_temp,
    "Brazil 1980-1999": bra_80_99_temp,
    "China 1960-1979": chn_60_79_temp,
    "China 1980-1999": chn_80_99_temp,
    "Germany 1960-1979": deu_60_79_temp,
    "Germany 1980-1999": deu_80_99_temp,
    "India 1960-1979": ind_60_79_temp,
    "India 1980-1999": ind_80_99_temp,
    
}
temp_dic_pd = pd.DataFrame(temp_dic)
temp_dic_pd
# Out:
#    Months  USA 1960-1979  USA 1980-1999  Brazil 1960-1979  Brazil 1980-1999  \
# 0     Jan     -10.593957      -9.621845         23.560257         23.795165
# 1     Feb      -8.789350      -8.451683         23.904940         24.204186
# 2     Mar      -4.371808      -3.776518         23.794841         24.032752
# 3     Apr       2.247250       2.673571         22.852692         23.190878
# 4     May       8.698442       9.254254         21.015294         21.388842
# 5     Jun      14.481749      14.923076         19.121112         19.461337
# 6     Jul      18.035866      18.226249         19.121817         19.487659
# 7     Aug      17.623427      17.891722         21.497949         21.932762
# 8     Sep      13.282027      13.545309         24.112174         24.537943
# 9     Oct       6.450370       6.414062         24.358089         24.893842
# 10    Nov      -1.464344      -0.960048         24.029829         24.402564
# ...

# %%
url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1960/1979/usa"
response = requests.get(url).json()
usa_60_79_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/usa"
response = requests.get(url).json()
usa_80_99_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1960/1979/chn"
response = requests.get(url).json()
chn_60_79_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/chn"
response = requests.get(url).json()
chn_80_99_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1960/1979/bra"
response = requests.get(url).json()
bra_60_79_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/bra"
response = requests.get(url).json()
bra_80_99_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1960/1979/deu"
response = requests.get(url).json()
deu_60_79_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/deu"
response = requests.get(url).json()
deu_80_99_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1960/1979/ind"
response = requests.get(url).json()
ind_60_79_rain = response[0]["monthVals"]

url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/mavg/pr/1980/1999/ind"
response = requests.get(url).json()
ind_80_99_rain = response[0]["monthVals"]

# print(json.dumps(response, indent=4, sort_keys=True))

# %%
rain_dic = {
    "Months": months,
    "USA 1960-1979": usa_60_79_rain,
    "USA 1980-1999": usa_80_99_rain,
    "Brazil 1960-1979": bra_60_79_rain,
    "Brazil 1980-1999": bra_80_99_rain,
    "China 1960-1979": chn_60_79_rain,
    "China 1980-1999": chn_80_99_rain,
    "Germany 1960-1979": deu_60_79_rain,
    "Germany 1980-1999": deu_80_99_rain,
    "India 1960-1979": ind_60_79_rain,
    "India 1980-1999": ind_80_99_rain,
    
}
rain_dic_pd = pd.DataFrame(rain_dic)
rain_dic_pd
# Out:
#    Months  USA 1960-1979  USA 1980-1999  Brazil 1960-1979  Brazil 1980-1999  \
# 0     Jan      55.374732      54.085429        184.466403        189.799095
# 1     Feb      46.398831      50.109668        174.155673        176.959991
# 2     Mar      60.749688      59.514374        197.546150        202.057251
# 3     Apr      63.058764      65.556613        177.478009        174.849032
# 4     May      69.755848      70.434940        131.416495        135.885713
# 5     Jun      69.744761      68.001146         73.425442         72.795561
# 6     Jul      73.794657      74.484280         25.917804         24.956051
# 7     Aug      77.709330      74.436758         20.793632         20.060217
# 8     Sep      75.702065      76.553649         39.654424         43.040256
# 9     Oct      70.893550      69.602309        119.910291        118.649452
# 10    Nov      60.838499      65.110554        154.567408        166.590330
# ...

# %%
path_1 = "csv/green_house_gas.csv"
green_house_gas = pd.read_csv(path_1)
green_house_gas_df = pd.DataFrame(green_house_gas)
green_house_gas_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1  Afghanistan          AFG
# 2       Angola          AGO
# 3      Albania          ALB
# 4      Andorra          AND
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
# 1  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
# 2  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
# 3  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
# 4  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE   NaN
#
#    1961  1962  1963  1964  1965     ...               2010          2011  \
# 0   NaN   NaN   NaN   NaN   NaN     ...                NaN           NaN
# 1   NaN   NaN   NaN   NaN   NaN     ...       17791.329902  17981.307287
# 2   NaN   NaN   NaN   NaN   NaN     ...       40029.392101  40878.651958
# ...

# %%
path_2 = "csv/rural_population.csv"
population = pd.read_csv(path_2)
population_df = pd.DataFrame(population)
population_df.head()
# Out:
#   Country Name Country Code    Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Rural population    SP.RUR.TOTL    26685.0
# 1  Afghanistan          AFG  Rural population    SP.RUR.TOTL  8240568.0
# 2       Angola          AGO  Rural population    SP.RUR.TOTL  5054316.0
# 3      Albania          ALB  Rural population    SP.RUR.TOTL  1114818.0
# 4      Andorra          AND  Rural population    SP.RUR.TOTL     5572.0
#
#         1961       1962       1963       1964       1965     ...       \
# 0    27297.0    27693.0    27934.0    28108.0    28278.0     ...
# 1  8370722.0  8506983.0  8649584.0  8798513.0  8954113.0     ...
# 2  5131812.0  5208828.0  5285253.0  5358588.0  5427638.0     ...
# 3  1146208.0  1180553.0  1214693.0  1248887.0  1282417.0     ...
# 4     5609.0     5616.0     5601.0     5554.0     5482.0     ...
#
#          2010        2011        2012        2013        2014        2015  \
# ...

# %%
path_3 = "csv/income_level.csv"
income_level = pd.read_csv(path_3)
income_level_df = pd.DataFrame(income_level)
income_level_df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  Mining is included in agriculture\nElectricty ...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN
